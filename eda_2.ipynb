# %%
import pandas as i
name=["Salman", 'Luquman', 'Jabbar','jawwad','Afzal']
age=[30,26,20,28,18]
course=['ML', 'DL','Python','programming','DS']
village=['Balwat' for i in range(6)]
dist=['Araria' for i in range(6)]
state=['BR' for i in range(6)]
ix=['A','B','C','D','E']
cols=['Name', 'Age','course','Village','dist','state']
df=i.DataFrame(zip(name,age,course,village,dist,state),
            columns=cols,
            index=ix)
df
# Out:
#       Name  Age       course Village    dist state
# A   Salman   30           ML  Balwat  Araria    BR
# B  Luquman   26           DL  Balwat  Araria    BR
# C   Jabbar   20       Python  Balwat  Araria    BR
# D   jawwad   28  programming  Balwat  Araria    BR
# E    Afzal   18           DS  Balwat  Araria    BR

# %%
df
# Out:
#       Name  Age       course Village    dist state
# A   Salman   30           ML  Balwat  Araria    BR
# B  Luquman   26           DL  Balwat  Araria    BR
# C   Jabbar   20       Python  Balwat  Araria    BR
# D   jawwad   28  programming  Balwat  Araria    BR
# E    Afzal   18           DS  Balwat  Araria    BR

# %%
salary=[50000 - 5000*i for i in range(5)]
df['salary']=salary
df
# Out:
#       Name  Age       course Village    dist state  salary
# A   Salman   30           ML  Balwat  Araria    BR   50000
# B  Luquman   26           DL  Balwat  Araria    BR   45000
# C   Jabbar   20       Python  Balwat  Araria    BR   40000
# D   jawwad   28  programming  Balwat  Araria    BR   35000
# E    Afzal   18           DS  Balwat  Araria    BR   30000

# %%
edu=[]
df['edu']="nan"
df
# Out:
#       Name  Age       course Village    dist state  edu
# A   Salman   30           ML  Balwat  Araria    BR  nan
# B  Luquman   26           DL  Balwat  Araria    BR  nan
# C   Jabbar   20       Python  Balwat  Araria    BR  nan
# D   jawwad   28  programming  Balwat  Araria    BR  nan
# E    Afzal   18           DS  Balwat  Araria    BR  nan

# %%
df
# Out:
#       Name  Age       course Village    dist state
# A   Salman   30           ML  Balwat  Araria    BR
# B  Luquman   26           DL  Balwat  Araria    BR
# C   Jabbar   20       Python  Balwat  Araria    BR
# D   jawwad   28  programming  Balwat  Araria    BR
# E    Afzal   18           DS  Balwat  Araria    BR

# %%
df["sal"]=10000

# %%
df
# Out:
#       Name  Age       course Village    dist state    sal
# A   Salman   30           ML  Balwat  Araria    BR  10000
# B  Luquman   26           DL  Balwat  Araria    BR  10000
# C   Jabbar   20       Python  Balwat  Araria    BR  10000
# D   jawwad   28  programming  Balwat  Araria    BR  10000
# E    Afzal   18           DS  Balwat  Araria    BR  10000

# %%
l=[]
l.append(df.iloc[0,6])
for i in df['sal'].iloc[1:]:
    j=l[-1]+500
    l.append(j)
df['sal']=l
df
# Out:
#       Name  Age       course Village    dist state    sal
# A   Salman   30           ML  Balwat  Araria    BR  10000
# B  Luquman   26           DL  Balwat  Araria    BR  10500
# C   Jabbar   20       Python  Balwat  Araria    BR  11000
# D   jawwad   28  programming  Balwat  Araria    BR  11500
# E    Afzal   18           DS  Balwat  Araria    BR  12000

# %%
df
# Out:
#       Name  Age       course Village    dist state  sal
# A   Salman   30           ML  Balwat  Araria    BR  250
# B  Luquman   26           DL  Balwat  Araria    BR  255
# C   Jabbar   20       Python  Balwat  Araria    BR  260
# D   jawwad   28  programming  Balwat  Araria    BR  265
# E    Afzal   18           DS  Balwat  Araria    BR  270

# %%
import pandas as pd
df2=pd.DataFrame()
l1=[i for i in range(2,10)]
l2=[i**2 for i in range(2,10)]
l3=[i**3 for i in range(2,10)]

df2['A']=l1
df2['B']=l2
df2['C']=l3
df2
# Out:
#    A   B    C
# 0  2   4    8
# 1  3   9   27
# 2  4  16   64
# 3  5  25  125
# 4  6  36  216
# 5  7  49  343
# 6  8  64  512
# 7  9  81  729

# %%
l4=[i**4 for i in range(2,10)]
df2['D']=l4
df2
# Out:
#    A   B    C     D
# 0  2   4    8    16
# 1  3   9   27    81
# 2  4  16   64   256
# 3  5  25  125   625
# 4  6  36  216  1296
# 5  7  49  343  2401
# 6  8  64  512  4096
# 7  9  81  729  6561

# %%
ix=['j','k','l','m','n','o','p','q']
df2['index']=ix
df2
# Out:
#    A   B    C     D index
# 0  2   4    8    16     j
# 1  3   9   27    81     k
# 2  4  16   64   256     l
# 3  5  25  125   625     m
# 4  6  36  216  1296     n
# 5  7  49  343  2401     o
# 6  8  64  512  4096     p
# 7  9  81  729  6561     q

# %%
df2.drop('index',axis=1)
# Out:
#    A   B    C     D
# 0  2   4    8    16
# 1  3   9   27    81
# 2  4  16   64   256
# 3  5  25  125   625
# 4  6  36  216  1296
# 5  7  49  343  2401
# 6  8  64  512  4096
# 7  9  81  729  6561

# %%
ix=['j','k','l','m','n','o','p','q']
index=ix
df2
# Out:
#    A   B    C     D index
# 0  2   4    8    16     j
# 1  3   9   27    81     k
# 2  4  16   64   256     l
# 3  5  25  125   625     m
# 4  6  36  216  1296     n
# 5  7  49  343  2401     o
# 6  8  64  512  4096     p
# 7  9  81  729  6561     q

# %%
df2.drop('index',axis=1)
# Out:
#    A   B    C     D
# 0  2   4    8    16
# 1  3   9   27    81
# 2  4  16   64   256
# 3  5  25  125   625
# 4  6  36  216  1296
# 5  7  49  343  2401
# 6  8  64  512  4096
# 7  9  81  729  6561

# %%
df2.set_index('index')
# Out:
#        A   B    C     D
# index
# j      2   4    8    16
# k      3   9   27    81
# l      4  16   64   256
# m      5  25  125   625
# n      6  36  216  1296
# o      7  49  343  2401
# p      8  64  512  4096
# q      9  81  729  6561

# %%
df2_ = df2.drop('index',axis=1)
df2_
# Out:
#    A   B    C     D
# 0  2   4    8    16
# 1  3   9   27    81
# 2  4  16   64   256
# 3  5  25  125   625
# 4  6  36  216  1296
# 5  7  49  343  2401
# 6  8  64  512  4096
# 7  9  81  729  6561

# %%
new_index = ['j', 'k', 'l', 'm', 'n', 'o', 'p', 'q']
df2.index = new_index
df2
# Out:
#    A   B    C     D index
# j  2   4    8    16     j
# k  3   9   27    81     k
# l  4  16   64   256     l
# m  5  25  125   625     m
# n  6  36  216  1296     n
# o  7  49  343  2401     o
# p  8  64  512  4096     p
# q  9  81  729  6561     q

# %%
df2.drop('index',axis=1)
# Out:
#    A   B    C     D
# j  2   4    8    16
# k  3   9   27    81
# l  4  16   64   256
# m  5  25  125   625
# n  6  36  216  1296
# o  7  49  343  2401
# p  8  64  512  4096
# q  9  81  729  6561

# %%
import pandas as pd

# %%
# list to DataFrame
import pandas as pd
list=[1,2,3,4,5]
df= pd.DataFrame(list, columns=['numbers'])
(df)
# Out:
#    numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
import pandas as pd

dict={
    'id':[1,2,3],
    'name': ['azad','amir','salman'],
    'Age': [25, 30, 35]
}

df1=pd.DataFrame(dict)
print(df1)
# Out:
#    id    name  Age
# 0   1    azad   25
# 1   2    amir   30
# 2   3  salman   35

# %%
import pandas as pd

# Corrected dictionary definition
data = {
    'id': [1, 2, 3],
    'name': ['azad', 'amir', 'salman'],
    'Age': [25, 30, 35]
}

# Convert dictionary to DataFrame
df1 = pd.DataFrame(data)
df1
# Out:
#    id    name  Age
# 0   1    azad   25
# 1   2    amir   30
# 2   3  salman   35

# %%
import pandas as pd
 
data = {'name': ['nick', 'david', 'joe', 'ross'],
        'age': ['5', '10', '7', '6']}
new = pd.DataFrame.from_dict(data)
 
new
# Out:
#     name age
# 0   nick   5
# 1  david  10
# 2    joe   7
# 3   ross   6

# %%
l1=[1,2,3]
l2=['azad','arif','ahsan']
l3=dict(l1,l2)
print(l3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 l1=[1,2,3]
#       2 l2=['azad','arif','ahsan']
# ----> 3 l3=dict(l1,l2)
#       4 print(l3)
#
# TypeError: 'dict' object is not callable

# %%
a="hello"
    print(str(a))
# Out:
#   Cell In[27], line 2
#     print(str(a))
#     ^
# IndentationError: unexpected indent

# %%
a=[1,2,3]
print(a[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 a=[1,2,3]
# ----> 2 print(a[3])
#
# IndexError: list index out of range

# %%
for i in range(<stop>):
    print(i)
# Out:
#   Cell In[31], line 1
#     for i in range(<stop>):
#                    ^
# SyntaxError: invalid syntax

# %%
print(0)
print(1)
print(2)
# Out:
# 0
# 1
# 2
